# %% [markdown]
# # Load libraries

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import sys
import scipy.io
import os
import sys
from pathlib import Path
import pickle
from gc import collect
from glob import glob
from datetime import datetime
import traceback
from time import sleep
import matplotlib.dates as mdates
from mpl_toolkits.axes_grid1 import make_axes_locatable


#Important!! Make sure your current directory is the MHDTurbPy folder!
os.chdir("/Users/nokni/work/MHDTurbPy/")


# Make sure to use the local spedas
sys.path.insert(0, os.path.join(os.getcwd(), 'pyspedas'))
import pyspedas
from pyspedas.utilities import time_string
from pytplot import get_data


""" Import manual functions """

sys.path.insert(1, os.path.join(os.getcwd(), 'functions'))
import calc_diagnostics as calc
import TurbPy as turb
import general_functions as func
import Figures as figs
from   SEA import SEA


# Better figures
from matplotlib import pyplot as plt
plt.style.use(['science', 'scatter'])
plt.rcParams['text.usetex'] = True

os.environ["CDF_LIB"] = "/Applications/cdf/cdf/lib"
# Out:
# This unreleased version of SpacePy is not supported by the SpacePy team.

# %% [markdown]
# # Download data

# %%
from joblib import Parallel, delayed

# Choose PSP or SolO
sc                      = 1                                  # PSP:0, SolO:1

# If you only need to download 1 interval (dates wont matter if only_one_interval=0)
only_one_interval       = 0                                    # If you only want to check one interval

alfvenic_intervals      = True
cdf_lib_path            = '/Applications/cdf/cdf/lib'            # You will need to read cdf files. You have to specify the path
choose_working_dir      = '/Users/nokni/work/sc_data/'           # Working dir. Usually where you save raw data (a psp_data, and/or solar_orbiter_data folder will be created)

#User defined parameters
addit_time_around       =  12                                     # [start_time -addit_time_around [h], end_time + addit_time_around [h]]
high_resol_data         = True
subtract_rol_mean       = 1                                      # To estimate fluctuations of mag, vel field
rolling_window          = '1h'                                   # When estimating fluctuations, size of window (centered around -w/2 -w/2
gap_time_threshold      = 5                                      # Threshold for large gaps (units of seconds)
estimate_PSD            = 0                                      # Estimate magentic field powes spectral density (keep false)
estimate_PSD_V          = 0                                      # Estimate velocity field powes spectral density (keep false)
high_res_mag            = 0                                      # Use high resol or low resolution magnetic field data ( Choose either 1 or 0 respectively)
in_RTN                  = 1                                      # RTN or spacecraft frame ( We will usually use RTN)
f_min_spec              = 2e-3                                   # Integrate over [f_min_spec, f_max_spec]to estimate σc, σr 
f_max_spec              = 1e-2                                   #
step                    = '1H'                                  # Move starting point by step (in Hours)
duration                = '3H'                                  # Duration of interval (in Hours)
settings                =  {
                            'particle_mode': '9th_perih_cut',     # either: 'spc', 'span', '9th_perih_cut'
                            'apply_hampel' : True,                # Use hampelfilter to despike plasma data
                            'part_resol'   : 1000,                # Max resol of plasma data                [ms]
                            'MAG_resol'    : 1000                  # Max resol og magnetic field data        [ms]

                            } 

credentials         = { 'psp':{
                               'fields': {'username': 'mvelli', 'password': 'flds@psp'},
                               'sweap' : {'username': 'mvelli', 'password': '2019swe@pd@ta'}
                              }
                      }

if sc==0:
    vars_2_downnload = {'mag': None, 'span': None,'span-a': None, 'spc': None, 'qtn': None, 'ephem': None}
    
elif sc==1:
    vars_2_downnload = {'mag': None, 'qtn': None, 'swa': None, 'ephem': None} 
else:
    print('Not ready yet!')
    
    

# on the other hand if you have a list of intervals
load_dir_path           = '/Users/nokni/work/3d_anisotropy/radial_evolution/data/selected_intervals/'


if sc ==0:
    if alfvenic_intervals:
        
        load_path               = str(load_dir_path)+'all_psp_slow_alfvenic_intervals_final.pkl' # In case you have multiple days you want to download ()
        save_path               = '/Users/nokni/work/3d_anisotropy/radial_evolution/data/PSP/slow_alfvenic'                                # This will be connected with the parent of load_path
        
        
    else:
        load_path               = str(load_dir_path)+'all_psp_slow_non_alfvenic_intervals_nikos.pkl' # In case you have multiple days you want to download ()
        save_path               = '/Users/nokni/work/3d_anisotropy/radial_evolution/data/PSP/slow_non_alfvenic'                                # This will be connected with the parent of load_path

elif sc ==1:
    if alfvenic_intervals:
        
        load_path               = str(load_dir_path)+'solo_alfvenic_raffaela_intervals.pkl' # In case you have multiple days you want to download ()
        save_path               = '/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic'                                # This will be connected with the parent of load_path
        
        
    # else:
    #     load_path               = str(load_dir_path)+'all_psp_slow_non_alfvenic_intervals_nikos.pkl' # In case you have multiple days you want to download ()
    #     save_path      
else:
    print('under consruction')

    

# Change to to specified working dir
os.chdir(choose_working_dir)


# load dataframe
df                      =  pd.read_pickle(load_path)

# Define final path
final_path              =  Path(save_path)


# Call function
Parallel(n_jobs=-1)(delayed(data_analysis.download_files)(ok, 
                                                            df, 
                                                            final_path, 
                                                            only_one_interval, 
                                                            step, 
                                                            duration, 
                                                            addit_time_around, 
                                                            settings, 
                                                            vars_2_downnload, 
                                                            cdf_lib_path, 
                                                            credentials, 
                                                            gap_time_threshold, 
                                                            estimate_PSD_V, 
                                                            subtract_rol_mean, 
                                                            rolling_window, 
                                                            f_min_spec, 
                                                            f_max_spec, 
                                                            estimate_PSD, 
                                                            sc, 
                                                            high_resol_data, 
                                                            in_RTN) for ok in range(len(df)))
# Out:
# 02-Oct-23 11:50:06: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2020/
# 02-Oct-23 11:50:06: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2020/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2020/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2020/solo_l2_mag-rtn-burst_20201021_v02.cdf
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2020/solo_l2_mag-rtn-burst_20200805_v02.cdf
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2020/solo_l2_mag-rtn-burst_20200802_v03.cdf
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210428_v02.cdf
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210507_v02.cdf
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210506_v02.cdf
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2020/solo_l2_mag-rtn-burst_20200806_v02.cdf
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2020/solo_l2_mag-rtn-burst_20200803_v03.cdf
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210429_v02.cdf
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2020/solo_l2_mag-rtn-burst_20201022_v02.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 276, in LoadTimeSeriesSOLO
#     dfmag                 = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfmag)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'NoneType' object has no attribute 'sort_index'
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210508_v02.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 276, in LoadTimeSeriesSOLO
#     dfmag                 = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfmag)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'NoneType' object has no attribute 'sort_index'
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210507_v02.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 294, in LoadTimeSeriesSOLO
#     dfpar = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfpar)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'tuple' object has no attribute 'sort_index'
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 276, in LoadTimeSeriesSOLO
#     dfmag                 = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfmag)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'NoneType' object has no attribute 'sort_index'
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 294, in LoadTimeSeriesSOLO
#     dfpar = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfpar)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'tuple' object has no attribute 'sort_index'
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2020/
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210429_v02.cdf
# 02-Oct-23 11:50:07: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210517_v02.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 276, in LoadTimeSeriesSOLO
#     dfmag                 = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfmag)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'NoneType' object has no attribute 'sort_index'
# 02-Oct-23 11:50:07: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210528_v02.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210520_v02.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210717_v01.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210825_v02.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210612_v01.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210826_v02.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210901_v01.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210611_v01.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210810_v02.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210828_v02.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2020/solo_l2_swa-pas-grnd-mom_20200802_v03.cdf
# 02-Oct-23 11:50:08: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210829_v01.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/util/connection.py", line 95, in create_connection
#     raise err
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 1040, in _validate_conn
#     conn.connect()
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connection.py", line 358, in connect
#     self.sock = conn = self._new_conn()
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f8f38699690>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 785, in urlopen
#     retries = retries.increment(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='cdaweb.gsfc.nasa.gov', port=443): Max retries exceeded with url: /WS/cdasr/1/dataviews/sp_phys/datasets (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f8f38699690>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 315, in LoadTimeSeriesSOLO
#     dfdis                = download_ephem_SOLO(t0, t1, cdf_lib_path)
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 187, in download_ephem_SOLO
#     status, data = cdas.get_data('SOLO_HELIO1DAY_POSITION', ['RAD_AU','SE_LAT','SE_LON','HG_LAT','HG_LON','HGI_LAT','HGI_LON'], time[0], time[1])
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/cdasws/__init__.py", line 1255, in get_data
#     status_code, data_result = self.get_data_result(data_request,
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/cdasws/__init__.py", line 855, in get_data_result
#     response = self._session.post(url, data=data_request.json(),
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/sessions.py", line 577, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='cdaweb.gsfc.nasa.gov', port=443): Max retries exceeded with url: /WS/cdasr/1/dataviews/sp_phys/datasets (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f8f38699690>: Failed to establish a new connection: [Errno 61] Connection refused'))
# NoneType: None
# 02-Oct-23 11:50:09: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:09: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210518_v02.cdf
# 02-Oct-23 11:50:09: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210430_v02.cdf
# 02-Oct-23 11:50:09: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210718_v01.cdf
# 02-Oct-23 11:50:09: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2020/solo_l2_swa-pas-grnd-mom_20200803_v03.cdf
# 02-Oct-23 11:50:09: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# NoneType: None
# 02-Oct-23 11:50:09: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:10: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2020/solo_l2_swa-pas-grnd-mom_20200804_v03.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 276, in LoadTimeSeriesSOLO
#     dfmag                 = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfmag)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'NoneType' object has no attribute 'sort_index'
# 02-Oct-23 11:50:10: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:10: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210923_v02.cdf
# 02-Oct-23 11:50:10: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210826_v02.cdf
# 02-Oct-23 11:50:10: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-normal/2020/
# 02-Oct-23 11:50:10: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210924_v02.cdf
# 02-Oct-23 11:50:10: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210506_v03.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210506_v03.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 294, in LoadTimeSeriesSOLO
#     dfpar = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfpar)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'tuple' object has no attribute 'sort_index'
# 02-Oct-23 11:50:11: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2020/solo_l2_mag-rtn-normal_20201021_v02.cdf
# 02-Oct-23 11:50:11: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210521_v02.cdf
# 02-Oct-23 11:50:11: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210902_v01.cdf
# 02-Oct-23 11:50:11: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210506_v03.cdf
# 02-Oct-23 11:50:11: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210522_v02.cdf
# 02-Oct-23 11:50:11: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210507_v03.cdf
# 02-Oct-23 11:50:11: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# 02-Oct-23 11:50:11: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-normal/2021/
# NoneType: None
# 02-Oct-23 11:50:12: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:12: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210508_v03.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 276, in LoadTimeSeriesSOLO
#     dfmag                 = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfmag)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'NoneType' object has no attribute 'sort_index'
# 02-Oct-23 11:50:12: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:12: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210924_v03.cdf
# 02-Oct-23 11:50:12: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2021/solo_l2_mag-rtn-normal_20210517_v02.cdf
# 02-Oct-23 11:50:12: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210903_v01.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 276, in LoadTimeSeriesSOLO
#     dfmag                 = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfmag)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'NoneType' object has no attribute 'sort_index'
# 02-Oct-23 11:50:13: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:13: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210612_v01.cdf
# 02-Oct-23 11:50:13: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210613_v01.cdf
# 02-Oct-23 11:50:13: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# 02-Oct-23 11:50:13: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210811_v02.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py", line 507, in final_func
#     dfpar                                             = func.use_dates_return_elements_of_df_inbetween(dfmag.index[0], dfmag.index[-1], dfpar)
# AttributeError: 'NoneType' object has no attribute 'index'
# 02-Oct-23 11:50:13: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:13: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210613_v01.cdf
# 02-Oct-23 11:50:13: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-normal/2020/
# 02-Oct-23 11:50:14: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210924_v02.cdf
# 02-Oct-23 11:50:14: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2020/solo_l2_mag-rtn-normal_20200805_v02.cdf
# 02-Oct-23 11:50:14: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210925_v02.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 276, in LoadTimeSeriesSOLO
#     dfmag                 = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfmag)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'NoneType' object has no attribute 'sort_index'
# 02-Oct-23 11:50:14: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:14: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2020/solo_l2_mag-rtn-normal_20200806_v02.cdf
# 02-Oct-23 11:50:14: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210719_v01.cdf to solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210719_v01.cdf
# 02-Oct-23 11:50:15: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-normal/2021/
# 02-Oct-23 11:50:15: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py", line 507, in final_func
#     dfpar                                             = func.use_dates_return_elements_of_df_inbetween(dfmag.index[0], dfmag.index[-1], dfpar)
# AttributeError: 'NoneType' object has no attribute 'index'
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 294, in LoadTimeSeriesSOLO
#     dfpar = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfpar)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'tuple' object has no attribute 'sort_index'
# 02-Oct-23 11:50:15: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2020/solo_l2_mag-rtn-normal_20201022_v02.cdf
# 02-Oct-23 11:50:15: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:15: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210901_v03.cdf
# 02-Oct-23 11:50:15: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210429_v03.cdf
# 02-Oct-23 11:50:15: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2021/solo_l2_mag-rtn-normal_20210520_v02.cdf
# 02-Oct-23 11:50:15: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210928_v02.cdf
# 02-Oct-23 11:50:16: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2021/solo_l2_mag-rtn-normal_20210521_v02.cdf
# NoneType: None
# 02-Oct-23 11:50:16: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 276, in LoadTimeSeriesSOLO
#     dfmag                 = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfmag)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'NoneType' object has no attribute 'sort_index'
# 02-Oct-23 11:50:16: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:16: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210929_v02.cdf
# 02-Oct-23 11:50:16: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-normal/2021/
# 02-Oct-23 11:50:16: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2021/solo_l2_mag-rtn-normal_20210522_v02.cdf
# 02-Oct-23 11:50:16: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210902_v03.cdf
# 02-Oct-23 11:50:16: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210430_v03.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210430_v03.cdf
# 02-Oct-23 11:50:17: /Users/nokni/work/MHDTurbPy/functions/general_functions.py:1919: RuntimeWarning: Mean of empty slice
#   return np.nanmean((df.dropna().index.to_series().diff() / np.timedelta64(1, 's')))
#
# 02-Oct-23 11:50:17: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:17: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210430_v03.cdf
# 02-Oct-23 11:50:17: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210922_v03.cdf
# 02-Oct-23 11:50:17: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2021/solo_l2_mag-rtn-normal_20210612_v01.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 294, in LoadTimeSeriesSOLO
#     dfpar = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfpar)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'tuple' object has no attribute 'sort_index'
# 02-Oct-23 11:50:17: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210501_v03.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210501_v03.cdf
# 02-Oct-23 11:50:18: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py", line 507, in final_func
#     dfpar                                             = func.use_dates_return_elements_of_df_inbetween(dfmag.index[0], dfmag.index[-1], dfpar)
# AttributeError: 'NoneType' object has no attribute 'index'
# 02-Oct-23 11:50:18: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210611_v03.cdf
# 02-Oct-23 11:50:18: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# NoneType: None
# 02-Oct-23 11:50:18: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:18: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210612_v03.cdf
# 02-Oct-23 11:50:18: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2020/
# 02-Oct-23 11:50:18: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211013_v01.cdf
# 02-Oct-23 11:50:18: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211008_v01.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 276, in LoadTimeSeriesSOLO
#     dfmag                 = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfmag)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'NoneType' object has no attribute 'sort_index'
# 02-Oct-23 11:50:18: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:18: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210501_v03.cdf
# 02-Oct-23 11:50:18: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210613_v03.cdf
# 02-Oct-23 11:50:18: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2020/solo_l2_swa-pas-grnd-mom_20200805_v03.cdf
# 02-Oct-23 11:50:19: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211014_v01.cdf
# 02-Oct-23 11:50:19: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211015_v01.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/util/connection.py", line 95, in create_connection
#     raise err
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 1040, in _validate_conn
#     conn.connect()
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connection.py", line 358, in connect
#     self.sock = conn = self._new_conn()
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f7aa8cbd780>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 785, in urlopen
#     retries = retries.increment(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='cdaweb.gsfc.nasa.gov', port=443): Max retries exceeded with url: /WS/cdasr/1/dataviews/sp_phys/datasets (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f7aa8cbd780>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 315, in LoadTimeSeriesSOLO
#     dfdis                = download_ephem_SOLO(t0, t1, cdf_lib_path)
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 187, in download_ephem_SOLO
#     status, data = cdas.get_data('SOLO_HELIO1DAY_POSITION', ['RAD_AU','SE_LAT','SE_LON','HG_LAT','HG_LON','HGI_LAT','HGI_LON'], time[0], time[1])
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/cdasws/__init__.py", line 1255, in get_data
#     status_code, data_result = self.get_data_result(data_request,
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/cdasws/__init__.py", line 855, in get_data_result
#     response = self._session.post(url, data=data_request.json(),
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/sessions.py", line 577, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='cdaweb.gsfc.nasa.gov', port=443): Max retries exceeded with url: /WS/cdasr/1/dataviews/sp_phys/datasets (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f7aa8cbd780>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py", line 507, in final_func
#     dfpar                                             = func.use_dates_return_elements_of_df_inbetween(dfmag.index[0], dfmag.index[-1], dfpar)
# AttributeError: 'NoneType' object has no attribute 'index'
# 02-Oct-23 11:50:19: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:19: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2020/
# 02-Oct-23 11:50:19: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# 02-Oct-23 11:50:19: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211109_v01.cdf
# 02-Oct-23 11:50:20: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211009_v01.cdf
# 02-Oct-23 11:50:20: /Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py:282: RuntimeWarning: Mean of empty slice
#   r_psp            = np.nanmean(func.use_dates_return_elements_of_df_inbetween(mag_data.index[0], mag_data.index[-1], dist['Dist_au']))
#
# 02-Oct-23 11:50:20: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py", line 507, in final_func
#     dfpar                                             = func.use_dates_return_elements_of_df_inbetween(dfmag.index[0], dfmag.index[-1], dfpar)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 5039, in __getitem__
#     return getitem(key)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/pandas/core/arrays/datetimelike.py", line 341, in __getitem__
#     "Union[DatetimeLikeArrayT, DTScalarOrNaT]", super().__getitem__(key)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/pandas/core/arrays/_mixins.py", line 272, in __getitem__
#     result = self._ndarray[key]
# IndexError: index 0 is out of bounds for axis 0 with size 0
# 02-Oct-23 11:50:20: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211110_v01.cdf
# 02-Oct-23 11:50:20: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:20: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211111_v01.cdf
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# 02-Oct-23 11:50:20: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211108_v01.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 294, in LoadTimeSeriesSOLO
#     dfpar = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfpar)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'tuple' object has no attribute 'sort_index'
# Traceback (most recent call last):
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/util/connection.py", line 95, in create_connection
#     raise err
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 703, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     self._validate_conn(conn)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 1040, in _validate_conn
#     conn.connect()
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connection.py", line 358, in connect
#     self.sock = conn = self._new_conn()
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fe7c1771480>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/adapters.py", line 440, in send
#     resp = conn.urlopen(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/connectionpool.py", line 785, in urlopen
#     retries = retries.increment(
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host='cdaweb.gsfc.nasa.gov', port=443): Max retries exceeded with url: /WS/cdasr/1/dataviews/sp_phys/datasets (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe7c1771480>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 315, in LoadTimeSeriesSOLO
#     dfdis                = download_ephem_SOLO(t0, t1, cdf_lib_path)
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 187, in download_ephem_SOLO
#     status, data = cdas.get_data('SOLO_HELIO1DAY_POSITION', ['RAD_AU','SE_LAT','SE_LON','HG_LAT','HG_LON','HGI_LAT','HGI_LON'], time[0], time[1])
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/cdasws/__init__.py", line 1255, in get_data
#     status_code, data_result = self.get_data_result(data_request,
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/cdasws/__init__.py", line 855, in get_data_result
#     response = self._session.post(url, data=data_request.json(),
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/sessions.py", line 577, in post
#     return self.request('POST', url, data=data, json=json, **kwargs)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/sessions.py", line 529, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/sessions.py", line 645, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host='cdaweb.gsfc.nasa.gov', port=443): Max retries exceeded with url: /WS/cdasr/1/dataviews/sp_phys/datasets (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe7c1771480>: Failed to establish a new connection: [Errno 61] Connection refused'))
# NoneType: None
# 02-Oct-23 11:50:20: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:20: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211109_v01.cdf
# 02-Oct-23 11:50:21: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210612_v03.cdf
# 02-Oct-23 11:50:21: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:118: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2020-08-05_12-05-00_2020-08-05_16-58-00_sc_0/final_data.pkl'>
#   pickle.dump(final,open(path0.joinpath(foldername).joinpath("final_data.pkl"),'wb'))
#
# 02-Oct-23 11:50:21: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:119: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2020-08-05_12-05-00_2020-08-05_16-58-00_sc_0/general.pkl'>
#   pickle.dump(general,open(path0.joinpath(foldername).joinpath("general.pkl"),'wb'))
#
# 02-Oct-23 11:50:21: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:120: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2020-08-05_12-05-00_2020-08-05_16-58-00_sc_0/sig_c_sig_r.pkl'>
#   pickle.dump(sig_c_sig_r_timeseries,open(path0.joinpath(foldername).joinpath("sig_c_sig_r.pkl"),'wb'))
#
# 02-Oct-23 11:50:21: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:21: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211106_v01.cdf
# 02-Oct-23 11:50:21: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210613_v03.cdf
# 02-Oct-23 11:50:21: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211107_v01.cdf
# 02-Oct-23 11:50:21: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211108_v01.cdf
# 02-Oct-23 11:50:21: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:22: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211110_v01.cdf
# 02-Oct-23 11:50:22: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210520_v03.cdf
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/downloading_helpers/SOLO.py", line 294, in LoadTimeSeriesSOLO
#     dfpar = func.use_dates_return_elements_of_df_inbetween(ind1, ind2, dfpar)
#   File "/Users/nokni/work/MHDTurbPy/functions/general_functions.py", line 1096, in use_dates_return_elements_of_df_inbetween
#     df = df.sort_index(ascending=True)
# AttributeError: 'tuple' object has no attribute 'sort_index'
# 02-Oct-23 11:50:22: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211119_v01.cdf
# 02-Oct-23 11:50:22: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211120_v01.cdf
# 02-Oct-23 11:50:23: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# NoneType: None
# 02-Oct-23 11:50:23: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:23: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211123_v01.cdf
# 02-Oct-23 11:50:23: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2021/solo_l2_mag-rtn-normal_20210518_v02.cdf
# 02-Oct-23 11:50:24: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211124_v01.cdf
# 02-Oct-23 11:50:24: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py", line 507, in final_func
#     dfpar                                             = func.use_dates_return_elements_of_df_inbetween(dfmag.index[0], dfmag.index[-1], dfpar)
# AttributeError: 'NoneType' object has no attribute 'index'
# 02-Oct-23 11:50:24: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/
# 02-Oct-23 11:50:25: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211128_v01.cdf
# 02-Oct-23 11:50:25: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211129_v01.cdf
# 02-Oct-23 11:50:26: File is current: solar_orbiter_data/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20211130_v01.cdf
# 02-Oct-23 11:50:28: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:50:29: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-normal/2021/
# 02-Oct-23 11:50:29: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210517_v03.cdf
# 02-Oct-23 11:50:29: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2021/solo_l2_mag-rtn-normal_20210826_v02.cdf
# ...
# Error occurred while retrieving SWA data: HTTPSConnectionPool(host='spdf.gsfc.nasa.gov', port=443): Max retries exceeded with url: /pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210923_v03.cdf (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f90284f80a0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# No particle data!
# 25 - 42 failed!
# Time clip was applied to: B_RTN
# ok
# Ok, We have enough burst mag data
# 27 out of 42 finished
# 02-Oct-23 11:51:27: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:51:28: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211013_v03.cdf
# 02-Oct-23 11:51:28: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211014_v03.cdf
# 02-Oct-23 11:51:28: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211015_v03.cdf
# 02-Oct-23 11:51:32: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/mag/science/l2/rtn-normal/2021/
# 02-Oct-23 11:51:32: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# 02-Oct-23 11:51:32: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210717_v03.cdf
# 02-Oct-23 11:51:32: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:118: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-10-13_23-09-00_2021-10-14_16-15-00_sc_0/final_data.pkl'>
#   pickle.dump(final,open(path0.joinpath(foldername).joinpath("final_data.pkl"),'wb'))
#
# 02-Oct-23 11:51:32: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:119: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-10-13_23-09-00_2021-10-14_16-15-00_sc_0/general.pkl'>
#   pickle.dump(general,open(path0.joinpath(foldername).joinpath("general.pkl"),'wb'))
#
# 02-Oct-23 11:51:32: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:120: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-10-13_23-09-00_2021-10-14_16-15-00_sc_0/sig_c_sig_r.pkl'>
#   pickle.dump(sig_c_sig_r_timeseries,open(path0.joinpath(foldername).joinpath("sig_c_sig_r.pkl"),'wb'))
#
# 02-Oct-23 11:51:33: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210718_v03.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210718_v03.cdf
# This unreleased version of SpacePy is not supported by the SpacePy team.
# Error occurred while retrieving MAG data: HTTPSConnectionPool(host='spdf.gsfc.nasa.gov', port=443): Max retries exceeded with url: /pub/data/solar-orbiter/mag/science/l2/rtn-burst/2021/solo_l2_mag-rtn-burst_20210902_v01.cdf (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f829070d4b0>: Failed to establish a new connection: [Errno 61] Connection refused'))
# No MAG data!
# 19 - 42 failed!
# Time clip was applied to: B_RTN
# ok
# Ok, We have enough burst mag data
# 26 out of 42 finished
# 02-Oct-23 11:51:33: File is current: solar_orbiter_data/mag/science/l2/rtn-normal/2021/solo_l2_mag-rtn-normal_20211211_v01.cdf
# 02-Oct-23 11:51:33: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210718_v03.cdf
# 02-Oct-23 11:51:33: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210719_v03.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210719_v03.cdf
# 02-Oct-23 11:51:34: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20210719_v03.cdf
# 02-Oct-23 11:51:35: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# 02-Oct-23 11:51:35: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:51:36: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211211_v03.cdf
# 02-Oct-23 11:51:36: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:51:36: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211106_v03.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211106_v03.cdf
# 02-Oct-23 11:51:36: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# 02-Oct-23 11:51:37: /Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py:282: RuntimeWarning: Mean of empty slice
#   r_psp            = np.nanmean(func.use_dates_return_elements_of_df_inbetween(mag_data.index[0], mag_data.index[-1], dist['Dist_au']))
#
# 02-Oct-23 11:51:37: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:118: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-12-11_13-30-00_2021-12-11_21-38-00_sc_0/final_data.pkl'>
#   pickle.dump(final,open(path0.joinpath(foldername).joinpath("final_data.pkl"),'wb'))
#
# 02-Oct-23 11:51:37: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:119: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-12-11_13-30-00_2021-12-11_21-38-00_sc_0/general.pkl'>
#   pickle.dump(general,open(path0.joinpath(foldername).joinpath("general.pkl"),'wb'))
#
# 02-Oct-23 11:51:37: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:120: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-12-11_13-30-00_2021-12-11_21-38-00_sc_0/sig_c_sig_r.pkl'>
#   pickle.dump(sig_c_sig_r_timeseries,open(path0.joinpath(foldername).joinpath("sig_c_sig_r.pkl"),'wb'))
#
# 02-Oct-23 11:51:37: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211106_v03.cdf
# 02-Oct-23 11:51:37: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211224_v03.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211224_v03.cdf
# 02-Oct-23 11:51:37: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211107_v03.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211107_v03.cdf
# 02-Oct-23 11:51:37: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:118: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-07-18_03-17-00_2021-07-18_13-16-00_sc_0/final_data.pkl'>
#   pickle.dump(final,open(path0.joinpath(foldername).joinpath("final_data.pkl"),'wb'))
#
# 02-Oct-23 11:51:37: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:119: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-07-18_03-17-00_2021-07-18_13-16-00_sc_0/general.pkl'>
#   pickle.dump(general,open(path0.joinpath(foldername).joinpath("general.pkl"),'wb'))
#
# 02-Oct-23 11:51:37: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:120: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-07-18_03-17-00_2021-07-18_13-16-00_sc_0/sig_c_sig_r.pkl'>
#   pickle.dump(sig_c_sig_r_timeseries,open(path0.joinpath(foldername).joinpath("sig_c_sig_r.pkl"),'wb'))
#
# 02-Oct-23 11:51:37: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211224_v03.cdf
# 02-Oct-23 11:51:38: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211107_v03.cdf
# 02-Oct-23 11:51:38: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211225_v03.cdf
# 02-Oct-23 11:51:38: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211108_v03.cdf
# 02-Oct-23 11:51:38: File is current: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211226_v03.cdf
# 02-Oct-23 11:51:39: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# 02-Oct-23 11:51:39: /Users/nokni/work/MHDTurbPy/functions/general_functions.py:1919: RuntimeWarning: Mean of empty slice
#   return np.nanmean((df.dropna().index.to_series().diff() / np.timedelta64(1, 's')))
#
# Traceback (most recent call last):
#   File "/Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py", line 523, in final_func
#     res_particles, sig_c_sig_r_timeseries              = calc_particle_diagnostics(
#   File "/Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py", line 353, in calc_particle_diagnostics
#     part_quants = estimate_quants_particle_data(estimate_PSD_V, rolling_window, f_min_spec, f_max_spec,  in_rtn,  dfpar_interp, dfmag, subtract_rol_mean, smoothed)
#   File "/Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py", line 68, in estimate_quants_particle_data
#     freq_final          = str(int(dtv*1e3))+'ms'
# ValueError: cannot convert float NaN to integer
# 02-Oct-23 11:51:41: /Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py:170: RuntimeWarning: Mean of empty slice
#   alfv_speed, sw_speed = [np.nanmean(x, axis=0) for x in (Va_ts, V_ts)]
#
# 02-Oct-23 11:51:41: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:118: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-12-25_09-58-00_2021-12-25_23-05-00_sc_0/final_data.pkl'>
#   pickle.dump(final,open(path0.joinpath(foldername).joinpath("final_data.pkl"),'wb'))
#
# 02-Oct-23 11:51:41: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:119: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-12-25_09-58-00_2021-12-25_23-05-00_sc_0/general.pkl'>
#   pickle.dump(general,open(path0.joinpath(foldername).joinpath("general.pkl"),'wb'))
#
# 02-Oct-23 11:51:41: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:120: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2021-12-25_09-58-00_2021-12-25_23-05-00_sc_0/sig_c_sig_r.pkl'>
#   pickle.dump(sig_c_sig_r_timeseries,open(path0.joinpath(foldername).joinpath("sig_c_sig_r.pkl"),'wb'))
#
# 02-Oct-23 11:51:43: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2022/
# 02-Oct-23 11:51:44: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2022/solo_l2_swa-pas-grnd-mom_20220314_v02.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2022/solo_l2_swa-pas-grnd-mom_20220314_v02.cdf
# 02-Oct-23 11:51:44: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2022/solo_l2_swa-pas-grnd-mom_20220314_v02.cdf
# 02-Oct-23 11:51:45: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2022/solo_l2_swa-pas-grnd-mom_20220315_v02.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2022/solo_l2_swa-pas-grnd-mom_20220315_v02.cdf
# 02-Oct-23 11:51:45: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2022/solo_l2_swa-pas-grnd-mom_20220315_v02.cdf
# 02-Oct-23 11:51:46: /Users/nokni/opt/anaconda3/envs/numba/lib/python3.10/site-packages/spacepy/time.py:2367: UserWarning: Leapseconds may be out of date. Use spacepy.toolbox.update(leapsecs=True)
#   warnings.warn('Leapseconds may be out of date.'
#
# 02-Oct-23 11:51:46: /Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py:282: RuntimeWarning: Mean of empty slice
#   r_psp            = np.nanmean(func.use_dates_return_elements_of_df_inbetween(mag_data.index[0], mag_data.index[-1], dist['Dist_au']))
#
# 02-Oct-23 11:51:47: /Users/nokni/work/MHDTurbPy/functions/calc_diagnostics.py:170: RuntimeWarning: Mean of empty slice
#   alfv_speed, sw_speed = [np.nanmean(x, axis=0) for x in (Va_ts, V_ts)]
#
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# 02-Oct-23 11:51:48: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:118: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2022-03-14_13-14-00_2022-03-15_00-14-00_sc_0/final_data.pkl'>
#   pickle.dump(final,open(path0.joinpath(foldername).joinpath("final_data.pkl"),'wb'))
#
# 02-Oct-23 11:51:48: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:119: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2022-03-14_13-14-00_2022-03-15_00-14-00_sc_0/general.pkl'>
#   pickle.dump(general,open(path0.joinpath(foldername).joinpath("general.pkl"),'wb'))
#
# 02-Oct-23 11:51:48: /Users/nokni/work/3d_anisotropy/structure_functions_E1/functions/data_analysis.py:120: ResourceWarning: unclosed file <_io.BufferedWriter name='/Users/nokni/work/3d_anisotropy/radial_evolution/data/SolO/slow_alfvenic/2022-03-14_13-14-00_2022-03-15_00-14-00_sc_0/sig_c_sig_r.pkl'>
#   pickle.dump(sig_c_sig_r_timeseries,open(path0.joinpath(foldername).joinpath("sig_c_sig_r.pkl"),'wb'))
#
# 02-Oct-23 11:51:52: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/
# 02-Oct-23 11:51:53: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211119_v03.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211119_v03.cdf
# 02-Oct-23 11:51:53: Download complete: solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211119_v03.cdf
# 02-Oct-23 11:51:53: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2022/
# 02-Oct-23 11:51:54: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211120_v03.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2021/solo_l2_swa-pas-grnd-mom_20211120_v03.cdf
# 02-Oct-23 11:51:54: Downloading https://spdf.gsfc.nasa.gov/pub/data/solar-orbiter/swa/science/l2/pas-grnd-mom/2022/solo_l2_swa-pas-grnd-mom_20220317_v02.cdf to solar_orbiter_data/swa/science/l2/pas-grnd-mom/2022/solo_l2_swa-pas-grnd-mom_20220317_v02.cdf

# %%
import pandas as pd

# Load the DataFrame
df = pd.read_pickle(load_path)

# Convert 'End' and 'Start' columns to datetime if they are not already
df['End'] = pd.to_datetime(df['End'])
df['Start'] = pd.to_datetime(df['Start'])

# Calculate 'dts'
dts = (df['End'] - df['Start']).dt.total_seconds() / 3600

# Create a mask for rows where 'dts' is greater than 16
mask = dts > 16

# Create a new DataFrame to store the modified rows
new_rows = []

for index, row in df.iterrows():
    if mask[index]:
        duration_hours = (row['End'] - row['Start']).total_seconds() / 3600
        overlap_duration = duration_hours * 0.5
        
        first_interval = {
            'Start': row['Start'],
            'End': row['Start'] + pd.Timedelta(hours=overlap_duration)
        }
        second_interval = {
            'Start': row['Start'] + pd.Timedelta(hours=overlap_duration),
            'End': row['End']
        }
        
        new_rows.append(first_interval)
        new_rows.append(second_interval)
    else:
        new_rows.append(row)

# Create a new DataFrame from the modified rows
new_df = pd.DataFrame(new_rows)

# Display the new DataFrame
print(new_df)
